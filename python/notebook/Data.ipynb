# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import pickle

# %% [markdown]
# # Synthetic Data

# %%
from scipy.stats import uniform
from scipy.stats import norm 
N = 100
M = 25
x = uniform.rvs(size=(N,M))
for a in x:
    a.sort()
y = sp.sin(2*sp.pi*x) + norm.rvs(scale=0.3, size=(N,M))
with open('synthetic.dat', 'wb') as f:
    pickle.dump((x,y), f)

with open('synthetic.dat', 'rb') as f:
    x,y = pickle.load(f)
sx = np.linspace(0,1,25)
sy = sp.sin(2*sp.pi*sx)
plt.plot(sx,sy)
for i in range(20):
    plt.plot(x[i],y[i], 'o', color='red')

# %%
# %connect_info
# Out:
# {
#   "stdin_port": 62359,
#   "ip": "127.0.0.1",
#   "control_port": 62360,
#   "hb_port": 62361,
#   "signature_scheme": "hmac-sha256",
#   "key": "dcfb3764-0d2d-425e-a24d-2d5ec3642d34",
#   "shell_port": 62357,
#   "transport": "tcp",
#   "iopub_port": 62358
# }
#
# Paste the above JSON into a file, and connect with:
#     $> ipython <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> ipython <app> --existing kernel-0fbce37e-42a8-4350-90f7-4540f738e10a.json
# or even just:
#     $> ipython <app> --existing
# if this is the most recent IPython session you have started.
